# %% [markdown]
# # 회귀 모델 성능 평가

# %% [markdown]
# `sklearn.metrics`: 회귀 평가 지표를 사용할 수 있다

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_squared_log_error, r2_score

# %%
origin = np.array([1, 2, 3, 2, 3, 5, 4, 6, 5, 6, 7])
pred = np.array([1, 1, 2, 2, 3, 4, 4, 5, 5, 6, 7])

MAE = mean_absolute_error(origin, pred)
MSE = mean_squared_error(origin, pred)
RMSE = np.sqrt(MSE)
MSLE = mean_squared_log_error(origin, pred)
RMSLE = np.sqrt(mean_squared_log_error(origin, pred))
R2 = r2_score(origin, pred)

# %%
print('MAE:', round(MAE, 3))
print('MSE:', round(MSE, 3))
print('RMSE:', round(RMSE, 3))
print('MSLE:', round(MSLE, 3))
print('RMSLE:', round(RMSLE, 3))
print('R2:', round(R2, 3))
# Out:
# MAE: 0.364
# MSE: 0.364
# RMSE: 0.603
# MSLE: 0.028
# RMSLE: 0.166
# R2: 0.895
